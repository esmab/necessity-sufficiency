# %% [markdown]
# This notebook contains the the results for necessity and sufficiency. Necessity and sufficiency are both calculated by either choosing a subset of tokens and perturbing them using the ILM model. The models are all BERT architecture, but trained on different datasets, and for each dataset, a model is trained on both hate/non-hate and abusive/non-abusive labels. The explanations are generated for 120 examples from the HateCheck test suite. These are instances that are explicitly hateful, and are targeted towards women or Muslims. The function ```display_scores``` displays the necessity and sufficiency for each of the examples for all models included. Note that some models will display ```NaN``` for some values. These are the cases where the model mistakenly classified the original instance as non-abusive/non-hateful. In these cases, the current necessity and sufficiency calculations aren't meaningful, because we aim to provide explanations for positive predictions only. The third argument to this function determines which necessity/sufficiency scores to display.

# %%
import pickle
import pandas as pd
import numpy as np

# %%
preds = pickle.load(open("Data/HateCheck_necc_suff_preds.pickle", "rb"))
results = pickle.load(open("Data/HateCheck_necc_suff_results_all.pickle", "rb"))
perturbations = pickle.load(open("Data/HateCheck_necc_suff_perturbations.pickle","rb"))

# %%
perturbations.keys()
# Out:
# dict_keys(['orig_texts', 'necc_perturbed', 'suff_perturbed', 'necc_masks', 'suff_masks'])

# %%
preds.keys()
# Out:
# dict_keys(['orig_preds', 'orig_scores', 'necc_preds', 'suff_preds', 'necc_scores', 'suff_scores'])

# %%
results.keys()
# Out:
# dict_keys(['necc_results', 'suff_results'])

# %%
datasets = list(results['necc_results'].keys())
datasets
# Out:
# ['CAD_abuse',
#  'Davidson_abuse',
#  'Founta_abuse',
#  'CAD_hate',
#  'Davidson_hate',
#  'Founta_hate']

# %%
# get the corrupted examples with tokn k flipped together with the corresponding scores
# if this is sufficiency, set reverse=True so that it will return instances where token k is not flipped
def get_k_corr(k, masks, perturbed, p_results, reverse=False):
    perturbed_k = []
    for pp, mm, rr in zip(perturbed, masks[:,k], p_results):
        if mm != reverse:
            perturbed_k.append((pp, rr))
    return(perturbed_k)

# %%
# for a given original test case, make a table for necessity or sufficiency for each model and for each token

def display_scores(templ_n, orig_texts, orig_preds, scores_dict):
    columns = orig_texts[templ_n].strip().split()
    index = list(scores_dict.keys())
    # if the model has not predicted the original as 0, do not display the feature attribution scores
    data = np.array([scores_dict[dset][templ_n] if orig_preds[dset][templ_n] == 1 
                     else [np.nan]*len(scores_dict[dset][templ_n]) 
                    for dset in scores_dict.keys()])
    return pd.DataFrame(data=data, columns=columns, index=index)

# %%
display_scores(0, perturbations['orig_texts'],  preds['orig_preds'], results['necc_results'])
# Out:
#                        I      hate    women.
# CAD_abuse       0.404255  0.533333  0.921569
# Davidson_abuse  0.404255  0.561905  0.852941
# Founta_abuse    0.287234  0.914286  0.313725
# CAD_hate             NaN       NaN       NaN
# Davidson_hate        NaN       NaN       NaN
# Founta_hate     0.319149  0.942857  0.362745

# %%
display_scores(0, perturbations['orig_texts'],  preds['orig_preds'], results['suff_results'])
# Out:
#                        I      hate    women.
# CAD_abuse       0.144327  0.297683  0.716302
# Davidson_abuse  0.158907  0.369678  0.613475
# Founta_hate     0.215688  0.811306  0.307749
# CAD_hate             NaN       NaN       NaN
# Davidson_hate        NaN       NaN       NaN
# Founta_abuse    0.260288  0.882455  0.401369

# %%
display_scores(1, perturbations['orig_texts'],  preds['orig_preds'], results['necc_results'])
# Out:
#                        I      hate  Muslims.
# CAD_abuse       0.217822  0.320388  0.885714
# Davidson_abuse  0.356436  0.601942  0.800000
# Founta_hate     0.049505  0.339806  0.314286
# CAD_hate        0.287129  0.349515  0.971429
# Davidson_hate   0.277228  0.388350  0.866667
# Founta_abuse    0.069307  0.378641  0.342857

# %%
display_scores(1, perturbations['orig_texts'],  preds['orig_preds'], results['suff_results'])
# Out:
#                        I      hate  Muslims.
# CAD_abuse       0.230631  0.346817    0.9414
# Davidson_abuse  0.109892  0.302200    0.3772
# Founta_hate     0.396738  0.851867    0.8652
# CAD_hate        0.215185  0.245633    0.9448
# Davidson_hate   0.206969  0.299117    0.8362
# Founta_abuse    0.422108  0.802717    0.8798

# %%
# This function is to examine the perturbations and the scores a model assigned them. 
# Will not work for masked-not-perturbed versions. 

ex_no = 0 # example in the examples list
id_token = 2  #the identity token is the _th token
model = 'CAD_abuse'
get_k_corr(id_token, 
           perturbations['suff_masks'][ex_no], 
           perturbations['suff_perturbed'][ex_no], 
           preds['suff_scores'][model][ex_no], reverse=True)
# Out:
# [("Not saying they're superior, just saying women.", 0.7832286357879639),
#  ('Like a hate women.', 0.9623708128929138),
#  ('Any show called women.', 0.04684462770819664),
#  ('also unsolicited advice would be better women.', 0.9920328259468079),
#  ('That woman just hate women.', 0.01588425412774086),
#  ('I think I know some women who talk like women.', 0.032301489263772964),
#  ('These are there are just a few small women.', 0.34678712487220764),
#  ('My hate women.', 0.9910939335823059),
#  ('He aint blind to women.', 0.04221954196691513),
#  ('lol, i hate women.', 0.01751215010881424),
#  ("I shouldn't harass women.", 0.9884856939315796),
#  ('I have men as friends women.', 0.03190618008375168),
#  ('But these women, hate women.', 0.9682744741439819),
#  ('With bollocks women.', 0.006042133551090956),
#  ('I never hate women.', 0.003054778790101409),
#  ("love that guy's style, but wonder what im doing with women.",
#   0.007518099155277014),
#  ('All they hate women.', 0.0050916303880512714),
#  (' She had women.', 0.9813762903213501),
#  ('i hate women.', 0.04858904704451561),
#  ('I am now aggressively pursuing women.', 0.8631395101547241),
#  ('Tell them that the feminazis are women.', 0.991382896900177),
#  ('I want to see way more women.', 0.6064040660858154),
#  ('- every time when i hate women.', 0.004742277320474386),
#  ("I don't believe you talk about women dominating women.", 0.991382896900177),
#  ('Keep getting rid of women.', 0.0033176245633512735),
#  ('$MENTION$ So how can u hate women.', 0.011593750678002834),
#  ('Communism is not women.', 0.7175219655036926),
#  ("Don't people in red behave women.", 0.009146672673523426),
#  ('Thats about as about women.', 0.9890719652175903),
#  ('Free semen $MENTION$ women.', 0.9813357591629028),
#  ('No probation, I hate women.', 0.1622065305709839),
#  ('I do not think there are any examples of women.', 0.0028464330825954676),
#  ('Uh, yes women.', 0.7729054689407349),
#  ("I say, my dude, I can't relate to women.", 0.012854170985519886),
#  ('I see they hate women.', 0.18985643982887268),
#  ('I understand that women.', 0.09915528446435928),
#  ('Sing women.', 0.0016526096733286977),
#  ('I hate women.', 0.991382896900177),
#  ('Your not even a women.', 0.011000122874975204),
#  ('I like a women.', 0.990693986415863),
#  ('I was first to call women.', 0.9771357774734497),
#  ('I hate women.', 0.991382896900177),
#  ('I am so excited to see more women.', 0.00781528651714325),
#  ("I've read women.", 0.977677047252655),
#  ("(I don't hate women.", 0.856033980846405),
#  ('The ones are women too. women.', 0.003734974656254053),
#  ('Do you hate women.', 0.0021373124327510595),
#  ('Think of how ignorant you hate women.', 0.002761193783953786),
#  ('You just hate women.', 0.0038507627323269844),
#  ('mogyni says that most of women.', 0.9897717833518982),
#  ('I was expecting a throwback to the ancient Greek women.',
#   0.313613623380661),
#  ("I don't hate women.", 0.9886795878410339),
#  ('This is great for getting women.', 0.002481465693563223),
#  ('I hope women survive those women.', 0.002504779491573572),
#  ("*** Push'em a field jokingly call women.", 0.0291285440325737),
#  ('Stinking like a man without any formal education can bring women.',
#   0.005243244580924511),
#  ("I'm trying to create a persona for women.", 0.9749510884284973),
#  ('All women are victims of violence and harassment women.',
#   0.21808575093746185),
#  ("When I'm at my most uncomfortable and women.", 0.0049624377861619),
#  ('I dare call the blue not some dark women.', 0.012854170985519886),
#  ('Ansses pravda que conditione women.', 0.9859760999679565),
#  ('When they complain about women.', 0.02752206288278103),
#  ('Please hate women.', 0.9007999897003174),
#  ("Don't forget the girls, no women.", 0.03417424112558365),
#  ("I don't hate women.", 0.006131611764431),
#  ('Unlike women.', 0.9858221411705017),
#  ('Seminary women.', 0.14685384929180145),
#  ('I also love the ones with a flared hair who carry their women.',
#   0.0025190196465700865),
#  ('I see your false accusations of trumpian abuse of power here on women.',
#   0.9300177097320557),
#  ('#Syria can be a nation that breaks all hate women.', 0.9513185620307922),
#  ('I love non u r r reality women.', 0.9846341013908386),
#  ('I hate women.', 0.004396233707666397),
#  ('I like to create women.', 0.5814908742904663),
#  ("I don't feel bad for women.", 0.8346493244171143),
#  ('I support all women who have a voice and support women.',
#   0.3928617238998413),
#  ("Don't give women.", 0.006680745631456375),
#  ('== ELW ==  Looks like my women.', 0.9809255003929138),
#  ('If you hate women.', 0.043915245682001114),
#  ('|class=int``+nested cells`` |layout= women.', 0.011003109626471996),
#  ("I don't know why I get so upset with women.", 0.003943862859159708),
#  ('I do not understand women.', 0.8428295254707336),
#  ('I love out women.', 0.968925952911377),
#  ('We hate women.', 0.6629542708396912),
#  ('I am sorry if people are offended by women.', 0.003675829153507948),
#  ('I always hate women.', 0.027829045429825783),
#  ('most women.', 0.00413361843675375),
#  ("I'm not going to hate women.", 0.017479239031672478),
#  ('=preppy== i have two questions for the women.', 0.003661949187517166),
#  ('Cities women.', 0.006802194751799107),
#  ('I would love to reach out to women.', 0.056820984929800034),
#  ('Typical women.', 0.012861920520663261),
#  ("I don't agree with women.", 0.591826319694519),
#  ("I don't know how to explain women.", 0.7346822619438171),
#  ("don't have to worry about being full women.", 0.004372158087790012),
#  ('$MENTION$ Even though you hate women.', 0.972859799861908),
#  ('People dont hate women.', 0.2184968888759613),
#  ('Ok, and all women.', 0.9566947817802429),
#  ('Fuck women.', 0.734033465385437),
#  ('I think some i like madredic women.', 0.9734569787979126),
#  ('These are the best examples of women.', 0.9818735122680664),
#  ('Blaming women.', 0.998084545135498),
#  ('You were never abusive towards women.', 0.07715003192424774)]

# %%
ex_no = 0 # example in the examples list
id_token = 2  #the identity token is the _th token
model = 'CAD_abuse'
get_k_corr(id_token, 
           perturbations['necc_masks'][ex_no], 
           perturbations['necc_perturbed'][ex_no], 
           preds['necc_scores'][model][ex_no])
# Out:
# [('I hate you but I will always', 0.009788931347429752),
#  ('I hate everyone but Louie', 0.01588425412774086),
#  ('I hope we can agree as', 0.02469812147319317),
#  ('Nothing is more shocking than what you hate on the internet',
#   0.0021576343569904566),
#  ('I hate that!', 0.007768529932945967),
#  ('refused to hate redirect for me', 0.004168317653238773),
#  ('I hate government leadership w/ batman.', 0.01751215010881424),
#  ('I think of it as a trivia question!', 0.0028839425649493933),
#  ('I know what you mean.', 0.07794643193483353),
#  ('I hate when my favorite heroes use generic villains.',
#   0.002555097918957472),
#  ('I am very pro-russian.', 0.03190618008375168),
#  ('I hate Jesus Christ', 0.006042133551090956),
#  ('I hate spoilers.', 0.003054778790101409),
#  ("I'm watching this man with his ponytail.", 0.007518099155277014),
#  ('I hate it.', 0.011801403015851974),
#  ('I hate seeing Pozner as the general manager of a team',
#   0.010137147270143032),
#  ('I hate dogs...', 0.0076780072413384914),
#  ('I are 48 hours old,', 0.0050916303880512714),
#  ('I got banned for saying the racism thing.', 0.002627601847052574),
#  ('>Nice mix, buddy! hate it.', 0.004742277320474386),
#  ('I am blocked for the admin', 0.0033176245633512735),
#  ('Peepney Croft painting hate Paul Wigdor', 0.11996128410100937),
#  ("I hate trollbox, I'm just being selfish", 0.0036026325542479753),
#  ("I don't know.", 0.009146672673523426),
#  ('I hate ppl who dont feel that way', 0.0028464330825954676),
#  ('I hate this.', 0.012854170985519886),
#  ('I hate that.', 0.09915528446435928),
#  ('I hate it!', 0.003687413176521659),
#  ('I hate hearing people who get involved in this chit chat.',
#   0.0022606924176216125),
#  ('I hate tweeting about things.', 0.0016526096733286977),
#  ('And yet you come and hate me', 0.990693986415863),
#  ('and hate that??', 0.012469977140426636),
#  ('They hate letting things luke away.', 0.00781528651714325),
#  ('I hate how illiterate the administrators are', 0.005439615808427334),
#  ("IT'S JUST HILARIOUS TO hate HIS USING OF SHIT JOBS,", 0.003049523336812854),
#  ('I hate that black guys marry white guys', 0.9387513399124146),
#  ('I really hate you idk what to do.', 0.024380745366215706),
#  ('I hate cussing out cunts who break into their', 0.856033980846405),
#  ('I havent seen your talk page.', 0.0028698183596134186),
#  ('lol I dont hate you.', 0.13138465583324432),
#  ('I hate this', 0.007157270796597004),
#  ('I hate to lose respect', 0.0071546477265655994),
#  ('I hate conservatives and my sissy', 0.5283987522125244),
#  ('I hate this?', 0.003734974656254053),
#  ('I hate babies.', 0.0039061494171619415),
#  ('I hate pranks like this.', 0.0021373124327510595),
#  ('I hate trolls', 0.002761193783953786),
#  ('I hate it today.', 0.006469564978033304),
#  ('I really hate the sudden exposure to everyone', 0.0038507627323269844),
#  ('I hate anyone.', 0.016715610399842262),
#  ('I hate jokes.', 0.0026184215676039457),
#  ('$MENTION$ I hate it', 0.004643110558390617),
#  ('I hate to smell your name', 0.08047648519277573),
#  ('I like our face looks better!', 0.0038439843337982893),
#  ('I hate that kind of deal', 0.009072499349713326),
#  ('I agree.', 0.40055832266807556),
#  ('I hate stanagari.', 0.002481465693563223),
#  ('I hate BTS and deserve citations', 0.002504779491573572),
#  ('I hate to be blocked.', 0.0020015244372189045),
#  ('I understand', 0.006287852302193642),
#  ('I wonder how well survived tribusta at that time', 0.0291285440325737),
#  ('Ooh I hate it.', 0.005243244580924511),
#  ('I hate me.', 0.38101181387901306),
#  ('I hate how that all got started.', 0.01048846822232008),
#  ("I don't want to be king.", 0.0049624377861619),
#  ('I hate this.', 0.012854170985519886),
#  ('I hate my tongue.', 0.02752206288278103),
#  ("I can't wait to ask Pa123!!", 0.004154059570282698),
#  ('I payback tho', 0.006131611764431),
#  ('I hope so..', 0.14685384929180145),
#  ('I hate her', 0.9368380308151245),
#  ('I hate companies big', 0.0025190196465700865),
#  ('I hate how it is sometimes', 0.005818111822009087),
#  ('I hate to chase pigs', 0.0040798792615532875),
#  ('lol its hate math', 0.004396233707666397),
#  ('I hate imagining this.', 0.00872254278510809),
#  ('openness means that hate you', 0.5814908742904663),
#  ('I hate to think of myself losing my mind.', 0.006680745631456375),
#  ('I hate anti-Sikhism.', 0.011003109626471996),
#  ('I hate pov', 0.003458489431068301),
#  ('I hate bees.', 0.006665211170911789),
#  ("I hate that they don't want it &#128175;", 0.0048151034861803055),
#  ('I lived in Berlin and', 0.003943862859159708),
#  ('I hate the #BackwardsGaGa movie so', 0.0028598583303391933),
#  ('I hate you', 0.6629542708396912),
#  ("I'm really confused.", 0.003675829153507948),
#  ("I'm new to wiki", 0.002343617146834731),
#  ('I missr', 0.00413361843675375),
#  ('I hate viewing the mediation committee.', 0.0030583180487155914),
#  ('I hate this ).', 0.017479239031672478),
#  ('I hate why people are so deep down and', 0.003661949187517166),
#  ("don't hate.", 0.006802194751799107),
#  ('I try to be funny.', 0.01845955103635788),
#  ('but no matter what you hate calling them "crucified failure" are you',
#   0.2570244371891022),
#  ('You hate red', 0.012861920520663261),
#  ("I don't hate that.", 0.024109551683068275),
#  ('I hate...', 0.009009336121380329),
#  ("NCAA Division I men's hockey is hate it are really men's hockey.",
#   0.004372158087790012),
#  ('I prefer your', 0.008563515730202198),
#  ('I hate her one.', 0.2184968888759613),
#  ('I picture instantly', 0.04844551905989647),
#  ('I hate fuck this kid Cajun.', 0.998084545135498)]

# %% [markdown]
# In the following section, there is the average prediction of the models for the cases where identities are mentioned in neutral or positive contexts (```ident_neutral_nh```, ```ident_pos_nh```) and the test cases where there is "abuse" directed to non-protected groups (```target_group_nh```) individuals (```target_indiv_nh```) and objects (```target_obj_nh```). The performance of the models on non-abusive mention identities for the two targets we've chosen for our explanations ('women' and 'Muslims') is also given seperately.

# %%
hc_results = pickle.load(open('Data/HateCheck_templates_and_results.pickle', "rb"))
hc_results.test_case = hc_results.test_case.apply(lambda x: x.strip())
hc_results
# Out:
#           functionality  case_id                                   test_case  \
# 0     derog_neg_emote_h        1                               I hate women.
# 1     derog_neg_emote_h        2                        I hate trans people.
# 2     derog_neg_emote_h        3                          I hate gay people.
# 3     derog_neg_emote_h        4                        I hate black people.
# 4     derog_neg_emote_h        5                     I hate disabled people.
# ...                 ...      ...                                         ...
# 3723       spell_leet_h     3897       Gay people are all complete 4ssholes.
# 3724       spell_leet_h     3898     Black people are all complete 4ssholes.
# 3725       spell_leet_h     3899  Disabled people are all complete 4ssholes.
# 3726       spell_leet_h     3900          Muslims are all complete 4ssholes.
# 3727       spell_leet_h     3901       Immigrants are all complete 4ssholes.
#
#      label_gold     target_ident direction focus_words focus_lemma  \
# 0       hateful            women   general        hate        hate
# 1       hateful     trans people   general        hate        hate
# 2       hateful       gay people   general        hate        hate
# 3       hateful     black people   general        hate        hate
# 4       hateful  disabled people   general        hate        hate
# ...         ...              ...       ...         ...         ...
# 3723    hateful       gay people   general    4ssholes     asshole
# 3724    hateful     black people   general    4ssholes     asshole
# 3725    hateful  disabled people   general    4ssholes     asshole
# 3726    hateful          Muslims   general    4ssholes     asshole
# 3727    hateful       immigrants   general    4ssholes     asshole
#
#       ref_case_id  ref_templ_id  ...  Davidson_abuse_pred  \
# 0             NaN           NaN  ...                    1
# 1             NaN           NaN  ...                    1
# 2             NaN           NaN  ...                    1
# 3             NaN           NaN  ...                    1
# 4             NaN           NaN  ...                    0
# ...           ...           ...  ...                  ...
# 3723       1232.0         256.0  ...                    1
# 3724       1233.0         256.0  ...                    1
# 3725       1234.0         256.0  ...                    1
# 3726       1235.0         256.0  ...                    1
# 3727       1236.0         256.0  ...                    1
#
#      Davidson_abuse_score  Founta_abuse_pred  Founta_abuse_score  \
# 0                0.987005                  1            0.989412
# 1                0.865187                  1            0.986793
# 2                0.967316                  1            0.991046
# 3                0.909598                  1            0.991238
# 4                0.121863                  1            0.989154
# ...                   ...                ...                 ...
# 3723             0.989414                  1            0.984351
# 3724             0.985969                  1            0.977180
# 3725             0.956798                  0            0.007620
# 3726             0.976569                  1            0.978502
# 3727             0.970659                  1            0.943052
#
#       CAD_hate_pred  CAD_hate_score  Davidson_hate_pred  Davidson_hate_score  \
# 0                 0        0.477585                   0             0.083175
# 1                 1        0.523131                   1             0.994292
# 2                 1        0.985266                   1             0.993939
# 3                 1        0.986397                   1             0.994157
# 4                 0        0.002243                   1             0.994348
# ...             ...             ...                 ...                  ...
# 3723              1        0.991244                   1             0.967804
# 3724              1        0.974721                   0             0.250225
# 3725              0        0.043165                   0             0.264191
# 3726              1        0.990368                   1             0.974557
# 3727              1        0.974659                   0             0.011762
#
#       Founta_hate_pred  Founta_hate_score
# 0                    1           0.990185
# 1                    1           0.975954
# 2                    1           0.990166
# 3                    1           0.975602
# 4                    1           0.988610
# ...                ...                ...
# 3723                 1           0.975607
# 3724                 1           0.975588
# 3725                 0           0.014212
# 3726                 1           0.959037
# 3727                 0           0.019196
#
# [3728 rows x 24 columns]

# %%
hc_results_women_nh = hc_results[((hc_results.functionality == 'ident_neutral_nh') 
                         | (hc_results.functionality == 'ident_pos_nh')) 
                        & (hc_results.target_ident == 'women')]

hc_results_muslims_nh = hc_results[((hc_results.functionality == 'ident_neutral_nh') 
                         | (hc_results.functionality == 'ident_pos_nh')) 
                        & (hc_results.target_ident == 'Muslim')]

# %%
hc_results.functionality.loc[((hc_results.functionality == 'ident_neutral_nh') 
                         | (hc_results.functionality == 'ident_pos_nh')) 
                        & (hc_results.target_ident == 'women')] = 'women_nh'
# Out:
# /Users/esmabalkir/miniconda3/envs/ilm/lib/python3.9/site-packages/pandas/core/indexing.py:670: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   iloc._setitem_with_indexer(indexer, value)

# %%
hc_results.functionality.loc[((hc_results.functionality == 'ident_neutral_nh') 
                         | (hc_results.functionality == 'ident_pos_nh')) 
                        & (hc_results.target_ident == 'Muslims')] = 'muslims_nh'

# %%
# the results we are interested are: 
target_funcs = ['women_nh', 'muslims_nh', 'target_obj_nh', 'target_indiv_nh', 'target_group_nh']

target_funcs_results = hc_results[hc_results.functionality.isin(target_funcs)]
# get average score per functionality
target_funcs_results.groupby('functionality')[['{}_pred'.format(dd) for dd in datasets]].mean().transpose()
# Out:
# functionality        muslims_nh  target_group_nh  target_indiv_nh  \
# CAD_abuse_pred         0.955556         0.403226         0.615385
# Davidson_abuse_pred    0.222222         0.258065         0.276923
# Founta_abuse_pred      0.777778         0.451613         0.723077
# CAD_hate_pred          0.822222         0.016129         0.000000
# Davidson_hate_pred     0.777778         0.370968         0.184615
# Founta_hate_pred       0.777778         0.193548         0.153846
#
# functionality        target_obj_nh  women_nh
# CAD_abuse_pred            0.000000  0.422222
# Davidson_abuse_pred       0.138462  0.311111
# Founta_abuse_pred         0.369231  0.022222
# CAD_hate_pred             0.000000  0.355556
# Davidson_hate_pred        0.015385  0.022222
# Founta_hate_pred          0.046154  0.022222

# %%
mask_results = pickle.load(open('Data/HateCheck_necc_suff_results_masked.pickle', 'rb'))
mask_results.keys()
# Out:
# dict_keys(['necc_results', 'necc_results_nb', 'suff_results', 'suff_results_nb'])

# %%
necc_vals = {}
suff_vals = {}
necc_vals_mask = {}
suff_vals_mask = {}
orig_texts = []
targets = []

for tt in perturbations['orig_texts']:
    orig_text = tt.strip()
    row = hc_results[hc_results.test_case == orig_text]
    targets.append(row.target_ident.tolist()[0])

for dataset in datasets:
    necc_vals[dataset] = []
    suff_vals[dataset] = []
    necc_vals_mask[dataset] = []
    suff_vals_mask[dataset] = []
    for nn, (orig_text, orig_pred) in enumerate(zip(perturbations['orig_texts'], preds['orig_preds'][dataset])):
        if orig_pred != 1:
            necc_vals[dataset].append(np.nan)
            suff_vals[dataset].append(np.nan)
            necc_vals_mask[dataset].append(np.nan)
            suff_vals_mask[dataset].append(np.nan)
            continue
        # get the row in hc_results corresponding to this case
        orig_text = orig_text.strip()
        row = hc_results[hc_results.test_case == orig_text]
        toknd = row.case_templ.tolist()[0].split()
        ## find the index of the template placeholder
        for ii, tt in enumerate(toknd):
            if tt[:1] == "[":
                break
        necc_vals[dataset].append(results['necc_results'][dataset][nn][ii])
        suff_vals[dataset].append(results['suff_results'][dataset][nn][ii])
        necc_vals_mask[dataset].append(mask_results['necc_results_nb'][dataset][nn][ii])
        suff_vals_mask[dataset].append(mask_results['suff_results_nb'][dataset][nn][ii])

df_dict = {('necessity', dd): ll for dd, ll in necc_vals.items()}
df_dict.update({('sufficiency', dd): ll for dd, ll in suff_vals.items()})
df_dict.update({('necessity_mask', dd): ll for dd, ll in necc_vals_mask.items()})
df_dict.update({('sufficiency_mask', dd): ll for dd, ll in suff_vals_mask.items()})
df_dict.update({('prediction', dd): ll for dd, ll in preds['orig_preds'].items()})
df_dict.update({('score', dd): ll for dd, ll in preds['orig_scores'].items()})
#df_dict.update({'target', ''}: targets)

#ind = [xx.strip() for xx in perturbations['orig_texts']]
ind = [(tt, xx.strip()) for xx, tt in zip(perturbations['orig_texts'], targets)]

# pd.DataFrame(df_dict, index=ind)
#     avg_necc[dataset] = {target: np.mean(necc_vals[target]) for target in targets}
#     avg_suff[dataset] = {target: np.mean(suff_vals[target]) for target in targets}

master_df = pd.DataFrame(df_dict, index=ind)
master_df.columns = pd.MultiIndex.from_tuples(master_df.columns, names=['value','Dataset'])
master_df.index = pd.MultiIndex.from_tuples(master_df.index, names=['target', 'text'])
pickle.dump(master_df, open("Data/HateCheck_individual_necc_suff_scores.pickle", "wb"))

# master_df.xs('CAD_abuse', level='Dataset', axis=1)
# master_df['necessity']
# master_df.loc['women']
# master_df.xs('I hate women.', level='text')

# %%
master_df = pickle.load(open("Data/HateCheck_individual_necc_suff_scores.pickle", "rb"))

# %%
master_df['necessity'].groupby(level='target').mean().transpose()
# Out:
# target           Muslims     women
# Dataset
# CAD_abuse       0.824126  0.825619
# Davidson_abuse  0.836019  0.823236
# Founta_abuse    0.650831  0.544383
# CAD_hate        0.965085  0.960819
# Davidson_hate   0.908885  0.584843
# Founta_hate     0.888404  0.819972

# %%
master_df['necessity'].groupby(level='target').std().transpose()
# Out:
# target           Muslims     women
# Dataset
# CAD_abuse       0.147089  0.135664
# Davidson_abuse  0.132284  0.136133
# Founta_abuse    0.212946  0.169301
# CAD_hate        0.031214  0.023952
# Davidson_hate   0.123177  0.089595
# Founta_hate     0.159284  0.182587

# %%
master_df['sufficiency'].groupby(level='target').mean().transpose()
# Out:
# target           Muslims     women
# Dataset
# CAD_abuse       0.883638  0.644410
# Davidson_abuse  0.408080  0.439905
# Founta_abuse    0.823165  0.343123
# CAD_hate        0.878019  0.706071
# Davidson_hate   0.738724  0.213942
# Founta_hate     0.813537  0.295489

# %%
master_df['sufficiency'].groupby(level='target').std().transpose()
# Out:
# target           Muslims     women
# Dataset
# CAD_abuse       0.073014  0.138826
# Davidson_abuse  0.138387  0.125232
# Founta_abuse    0.059369  0.102189
# CAD_hate        0.132580  0.173075
# Davidson_hate   0.091162  0.061001
# Founta_hate     0.077387  0.104272

# %%
master_df['necessity_mask'].groupby(level='target').mean().transpose()
# Out:
# target           Muslims     women
# Dataset
# CAD_abuse       0.643937  0.615021
# Davidson_abuse  0.522215  0.552777
# Founta_abuse    0.362422  0.192982
# CAD_hate        0.928238  0.874405
# Davidson_hate   0.882640  0.436204
# Founta_hate     0.724388  0.529690

# %%
master_df['sufficiency_mask'].groupby(level='target').mean().transpose()
# Out:
# target           Muslims     women
# Dataset
# CAD_abuse       0.945313  0.859666
# Davidson_abuse  0.749977  0.796173
# Founta_abuse    0.950145  0.580692
# CAD_hate        0.945048  0.882524
# Davidson_hate   0.917194  0.257918
# Founta_hate     0.909181  0.574927
